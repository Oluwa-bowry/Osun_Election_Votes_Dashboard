# %%
import pandas as pd
import numpy as np

# %%
 #Assuming your dataset is loaded into a DataFrame called 'df'
 # If not, you can load it with: 
gdf_sorted = pd.read_csv('OSUN_geocoded_cleaned_final.csv')

 # Step 1: Calculate z-scores for each party's votes
 # We’ll calculate the z-score for APC, LP, PDP, and NNPP votes
 parties = ['APC', 'LP', 'PDP', 'NNPP']
 for party in parties:
    # Calculate mean and standard deviation for the party's votes
    mean = gdf_sorted[party].mean()
    std = gdf_sorted[party].std()
    
    # Calculate z-score for each polling unit's votes for this party
    # Handle cases where std is 0 to avoid division by zero
    if std != 0:
        gdf_sorted[f'{party}_z_score'] = (gdf_sorted[party] - mean) / std
    else:
        gdf_sorted[f'{party}_z_score'] = 0  # If std is 0, set z-score to 0 (no 
# Step 2: Identify outliers based on z-scores
 # A common threshold for outliers is |z-score| > 3
 for party in parties:
     gdf_sorted[f'{party}_outlier'] = np.where(
         (gdf_sorted[f'{party}_z_score'].abs() > 3),  # Check if absolute z-score
         'Outlier',  # Label as outlier
         'Normal'    
        # Label as normal
    )
 # Step 3: Display the results
 # Show the polling units with their z-scores and outlier flags
print("Polling Units with Z-Scores and Outlier Flags for Each Party:")
display_columns = ['State', 'LGA', 'Ward', 'PU-Name', 'APC', 'APC_z_score', 'APC_outlier',
'LP', 'LP_z_score', 'LP_outlier', 'PDP', 'PDP_z_score', 'PDP_outlier',
'NNPP', 'NNPP_z_score', 'NNPP_outlier']
display(gdf_sorted[display_columns].head(10))  # Show first 10 rows for brevity
gdf_sorted.to_csv("OSUN_geocoded_cleaned_final.csv", index=False)
# Out:
# Polling Units with Z-Scores and Outlier Flags for Each Party:
#   State             LGA     Ward                         PU-Name  APC  \
# 0  OSUN  ATAKUMOSA EAST    IWARA                 TOWN HALL IWARA   44
# 1  OSUN  ATAKUMOSA EAST    IWARA             L.A. SCHOOL, IWIKUN   40
# 2  OSUN  ATAKUMOSA EAST    IWARA  METHODIST PRY. SCHOOL, AYETORO   14
# 3  OSUN  ATAKUMOSA EAST    IWARA            OPEN SPACE ODO-IWARA   25
# 4  OSUN  ATAKUMOSA EAST  IGANGAN       N.U.D PRY. SCHOL, IGANGAN   22
# 5  OSUN  ATAKUMOSA EAST  IGANGAN  APOSTOLIC PRY. SCHOOL, OKO-AGO    3
# 6  OSUN  ATAKUMOSA EAST  IGANGAN              OPEN SPACE AJUMOBI    4
# 7  OSUN  ATAKUMOSA EAST    IPOLE                TOWN HALL, IPOLE  123
# 8  OSUN  ATAKUMOSA EAST    IPOLE             TOWN HALL ODO IJESA  113
# 9  OSUN  ATAKUMOSA EAST    IPOLE            ST. ANDREW ISE-IJESA   84
#
#    APC_z_score APC_outlier   LP  LP_z_score LP_outlier  PDP  PDP_z_score  \
# ...

# %%
gdf = pd.read_csv('OSUN_geocoded_cleaned_finall.csv')

# %%
gdf.head()
# Out:
#   State             LGA     Ward       PU-Code  \
# 0  OSUN  ATAKUMOSA EAST    IWARA  29-01-01-001
# 1  OSUN  ATAKUMOSA EAST    IWARA  29-01-01-003
# 2  OSUN  ATAKUMOSA EAST    IWARA  29-01-01-004
# 3  OSUN  ATAKUMOSA EAST    IWARA  29-01-01-007
# 4  OSUN  ATAKUMOSA EAST  IGANGAN  29-01-02-001
#
#                           PU-Name  Accredited_Voters  Registered_Voters  \
# 0                 TOWN HALL IWARA                181                942
# 1             L.A. SCHOOL, IWIKUN                245                881
# 2  METHODIST PRY. SCHOOL, AYETORO                117                308
# 3            OPEN SPACE ODO-IWARA                187                538
# 4       N.U.D PRY. SCHOL, IGANGAN                187                558
#
#    Results_Found  Transcription_Count  Result_Sheet_Stamped  ...  \
# 0           True                   -1                 False  ...
# 1           True                   -1                 False  ...
# ...

# %%
gdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2248 entries, 0 to 2247
# Data columns (total 39 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   State                    2248 non-null   object
#  1   LGA                      2248 non-null   object
#  2   Ward                     2248 non-null   object
#  3   PU-Code                  2248 non-null   object
#  4   PU-Name                  2248 non-null   object
#  5   Accredited_Voters        2248 non-null   int64
#  6   Registered_Voters        2248 non-null   int64
#  7   Results_Found            2248 non-null   bool
#  8   Transcription_Count      2248 non-null   int64
#  9   Result_Sheet_Stamped     2248 non-null   bool
#  10  Result_Sheet_Corrected   2248 non-null   bool
#  11  Result_Sheet_Invalid     2248 non-null   bool
#  12  Result_Sheet_Unclear     2248 non-null   bool
#  13  Result_Sheet_Unsigned    2248 non-null   object
# ...
